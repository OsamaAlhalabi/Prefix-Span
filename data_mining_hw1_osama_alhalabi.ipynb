# %% [markdown]
# # Sequential Pattern Mining
# ## PrefixSpan Algorithm
# PrefixSpan extracts frequent sequences with depth-first search **(DFS)** by executing SDB projection operations **`recursively`**.

# %%
import pandas as pd
import numpy as np
import sys
from time import time

# %% [markdown]
# ### 1. Reading and Processing the Dataset

# %%
df = pd.read_csv("paths_finished_wiki.csv")
df.head(5)
# Out:
#     hashedIpAddress   timestamp  durationInSec  \
# 0  6a3701d319fc3754  1297740409          166.0
# 1  3824310e536af032  1344753412           88.0
# 2  415612e93584d30e  1349298640          138.0
# 3  64dd5cd342e3780c  1265613925           37.0
# 4  015245d773376aab  1366730828          175.0
#
#                                                 path  rating
# 0  14th_century;15th_century;16th_century;Pacific...     NaN
# 1  14th_century;Europe;Africa;Atlantic_slave_trad...     3.0
# 2  14th_century;Niger;Nigeria;British_Empire;Slav...     NaN
# 3     14th_century;Renaissance;Ancient_Greece;Greece     NaN
# 4  14th_century;Italy;Roman_Catholic_Church;HIV;R...     3.0

# %%
def data_preprocessing(df):
    res = []
    for path in df:
        elements = path.replace('<', '').replace('  ', ' ').lower().split(';') # separator
        tmp = []
        for element in elements:
            tmp.append(element.split())
        res.append(tmp)
    return res

# %%
data = data_preprocessing(df.path)

# %% [markdown]
# ### 2. PrefixSpan Algorithm Implementation

# %% [markdown]
# **An overview of how the algorithm works**
# <img src="imgs/prefix_span.png" width="600" height="300">

# %% [markdown]
# #### A simple example to follow along
# Note: this example exist in the slides of this subject

# %% [markdown]
# <img src="imgs/table1.png" width="400" height="200">

# %%
test_case = [[['a'], ['a', 'b', 'c'], ['a', 'c'], ['d'], ['c', 'f']],
 [['a', 'd'], ['c'], ['b', 'c'], ['a', 'e']],
 [['c', 'f'], ['a', 'b'], ['d', 'f'], ['c', 'b']],
 [['e', 'g'], ['a', 'f'], ['c'], ['b'], ['c']]]

sample_data = [
    ['C', 'A', 'G', 'A', 'A', 'G', 'T'],
    ['T', 'G', 'A', 'C', 'A', 'G'],
    ['G', 'A', 'A', 'G', 'T']
]

sample_data =[
[["a"], ["a", "b", "c"], ["a", "c"], ["c"]],
[["a"], ["c"], ["b", "c"]],
[["a", "b"], ["d"], ["c"], ["b"], ["c"]],
[["a"], ["c"], ["b"], ["c"]]
]

# %% [markdown]
# ### 2.1. Find all repeating sequences by  Scanning  the SDB
# **There are 3 basic cases**:
# 1. The sequence begins with `simultaneously` elements together which we put all together in parentheses, then one of these elements is taken and placed with '**_**'.
# 2. The sequence begins with the '**_**', then the first element of the sequence is simply ignored and the next element is added to the pattern as follows in the next case.
# 3. The sequence starts up with a regular element (as is the case in our dataset), then the strings are scanned normally.

# %%
def calc_frequent_items(sdb, pattern, min_sup):
    if sdb is None:
         return []
    
    if len(pattern) > 0:
        last_element = pattern[-1]
        last_sub_element = last_element[-1]
        
    else:
        last_element = []
    
    freqs = {} 
    p_freqs = {} # p refers to elements -sub_elements- that in parentheses '()'.
    res = []
    for seq in sdb: 
        # case 1
        fseq = seq[0]
        at_beginning = True
        for sub_element in last_element:
            if sub_element not in fseq:
                at_beginning = False
        if at_beginning and len(last_element) > 0:
            pattern_limit = fseq.index(last_sub_element)
            if pattern_limit < len(fseq) - 1:
                for sub_element in fseq[pattern_limit + 1:]:
                    if sub_element in p_freqs.keys():
                        p_freqs[sub_element] += 1
                    else:
                        p_freqs[sub_element] = 1        
        #case 2
        if '_' in seq[0]:
            for sub_element in seq[0][1:]:
                if sub_element in p_freqs:
                    p_freqs[sub_element] += 1
                else:
                    p_freqs[sub_element] = 1
            seq = seq[1:]
            
        #case 3
        visited = [] 
        for element in seq:
            for sub_element in element:
                if sub_element not in visited:
                    visited.append(sub_element)
                    if sub_element in freqs.keys():
                        freqs[sub_element] += 1
                    else:
                        freqs[sub_element] = 1
                        
                        
    for item in freqs.items():
        if item[1] >= min_sup:
            res.append(([item[0]], item[1]))
    for item in p_freqs.items():
        if item[1] >= min_sup:
            res.append((['_',item[0]], item[1]))      
    return sorted(res, key=lambda p: item[0]) #lambda is a virtual function

# %%
fi = calc_frequent_items(test_case,['a'] ,1)

# %%
fi
# Out:
# [(['a'], 4),
#  (['b'], 4),
#  (['c'], 4),
#  (['d'], 3),
#  (['f'], 3),
#  (['e'], 2),
#  (['g'], 1),
#  (['_', 'd'], 1)]

# %% [markdown]
# ### 2.2. Find subsets of sequential patterns
# The subsets of sequential patterns can be mined by constructing corresponding projected databases and mine each `recursively`. The projected databases as well as sequential patterns found in them are listed in the following Table
# <img src="imgs/table2.png" width="800" height="400">

# %%
def generate_SDB(sdb, pattern):
    res = []
    last_element = pattern[-1]
    last_sub_element = last_element[-1]
                        
    for seq in sdb:
        pp_sdb = [] # refers to partial proj. SDB
        
        for element in seq:
            # First Phase: check if the pattern 
            # check if the beginning of the sequence such like <(_ac)>.
            at_beginning = False
            if '_' in element:
                if len(last_element) > 1:
                    if last_element in element:
                        at_beginning = True
            # check if the beginning of the sequence is a normal case such like <ac>.
            else:
                at_beginning = True
                for sub_element in last_element:
                    if sub_element not in element:
                        at_beginning = False
                        break #check if the last element in pattern not at the end of the current element of the sequence
            if at_beginning:
                element_index = seq.index(element)
                pattern_limit_index = element.index(last_sub_element)
                if pattern_limit_index == len(element) - 1:
                    pp_sdb = seq[element_index + 1:]
                else:
                    pp_sdb = seq[element_index:]
                    celem = element[pattern_limit_index:]
                    celem[0] = '_'
                    pp_sdb[0] = celem
                break   
        if len(pp_sdb) != 0:
            res.append(pp_sdb)
    return res

# %%
# W = [[['a'],['b'],['c'],['a']]]
gs = generate_SDB(test_case, ['a'])
gs
# Out:
# [[['a', 'b', 'c'], ['a', 'c'], ['d'], ['c', 'f']],
#  [['_', 'd'], ['c'], ['b', 'c'], ['a', 'e']],
#  [['_', 'b'], ['d', 'f'], ['c', 'b']],
#  [['_', 'f'], ['c'], ['b'], ['c']]]

# %% [markdown]
# #### A method to concat a new element with the current pattern

# %%
def concat_patterns(p1, p2, s1, s2):
    if p1[0][0] == '_':
            tmp = p1[0]
            p1[0].remove('_')
            p2[-1].extend(tmp)
            p2.extend(p1[1:])
    else:
            p2.extend(p1)
    return (p2, min(s2, s1))

# %% [markdown]
# ### Based on above, the algorithm of PrefixSpan will be as follows.
# **Input:** A sequence database `(SDB)`, a starting  values for the pattern and support (\[\], 100000) by deafult and the minimum support `(min_sup)`.
#
# **Output:** The complete set of sequential patterns.

# %%
def prefix_span(sdb, pattern,sup, min_sup):
    patterns = []
    
    elements = calc_frequent_items(sdb, pattern, min_sup)
    for element in elements:
        
        p,sup = concat_patterns([element[0]],[pattern], element[1], sup) 
        patterns.append((p,sup))
        p_sdb = generate_SDB(sdb, p)
        p_patterns = prefix_span(p_sdb, p, sup, min_sup)
        patterns.extend(p_patterns)
    return patterns

# %% [markdown]
# #### A method to display the patterns and its support values

# %%
def print_results(res):    
    fnl_res = []
    for idx, pattern in enumerate(res):

        for element in pattern[0]:
            if len(element) == 0:
                    pattern[0].remove(element)
            for sub_element in element:
                if len(sub_element) == 0:
                    element.remove(sub_element)     
        fnl_res.append({
            'pattern' : str(pattern[0]).replace('[','').replace(']','').replace("\'",'').replace(',','->'),
            'support' : pattern[1]}) 

    return fnl_res

# %%
start_time = time()
# res=prefixSpan(data[:5000],[],10000,5)
res=prefix_span(sample_data,[],10000,2)
end_time = time()
elapsed = end_time - start_time
print('Elapsed time is %f seconds.' % elapsed)
# Out:
# Elapsed time is 0.000251 seconds.

# %%
print_results(res)
# Out:
# [{'pattern': 'a-> b', 'support': 4},
#  {'pattern': 'a-> b-> b-> c', 'support': 4},
#  {'pattern': 'a-> b-> b-> c-> c', 'support': 3},
#  {'pattern': 'a-> b-> b-> c', 'support': 2},
#  {'pattern': 'a-> b-> c', 'support': 4},
#  {'pattern': 'a-> b-> c-> c', 'support': 4},
#  {'pattern': 'a-> b-> c-> b', 'support': 3},
#  {'pattern': 'a-> b-> c-> b-> c', 'support': 2},
#  {'pattern': 'a-> b', 'support': 2},
#  {'pattern': 'b-> c', 'support': 4},
#  {'pattern': 'b-> c-> c', 'support': 3},
#  {'pattern': 'b-> c-> c-> c', 'support': 2},
#  {'pattern': 'b-> c', 'support': 2},
#  {'pattern': 'c', 'support': 4},
#  {'pattern': 'c-> c', 'support': 4},
#  {'pattern': 'c-> b', 'support': 3},
#  {'pattern': 'c-> b-> c', 'support': 2}]

# %%
start_time = time()
res=prefix_span(data[:5000],[],10000,5)
# res=prefix_span(test_case,[],10000,2)
end_time = time()
elapsed = end_time - start_time
print('Elapsed time is %f seconds.' % elapsed)
# Out:
# Elapsed time is 4.384469 seconds.

# %%
print_results(res)
# Out:
# [{'pattern': '14th_century', 'support': 141},
#  {'pattern': '14th_century-> 15th_century', 'support': 15},
#  {'pattern': '14th_century-> 15th_century-> 16th_century', 'support': 12},
#  {'pattern': '14th_century-> 16th_century', 'support': 12},
#  {'pattern': '14th_century-> atlantic_ocean', 'support': 6},
#  {'pattern': '14th_century-> africa', 'support': 6},
#  {'pattern': '14th_century-> africa-> atlantic_slave_trade', 'support': 6},
#  {'pattern': '14th_century-> africa-> atlantic_slave_trade-> african_slave_trade',
#   'support': 6},
#  {'pattern': '14th_century-> africa-> african_slave_trade', 'support': 6},
#  {'pattern': '14th_century-> atlantic_slave_trade', 'support': 6},
#  {'pattern': '14th_century-> atlantic_slave_trade-> african_slave_trade',
#   'support': 6},
#  {'pattern': '14th_century-> african_slave_trade', 'support': 6},
#  {'pattern': '14th_century-> europe', 'support': 6},
#  {'pattern': '14th_century-> europe-> united_states', 'support': 6},
#  {'pattern': '14th_century-> renaissance', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> rain', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> rain-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> isaac_newton', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> isaac_newton-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> renaissance-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> leonardo_da_vinci', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> leonardo_da_vinci-> water',
#   'support': 6},
#  {'pattern': '14th_century-> renaissance-> leonardo_da_vinci-> water-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> renaissance-> leonardo_da_vinci-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> renaissance-> water', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> water-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> color', 'support': 6},
#  {'pattern': '14th_century-> renaissance-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> president_of_the_united_states', 'support': 6},
#  {'pattern': '14th_century-> president_of_the_united_states-> john_f._kennedy',
#   'support': 6},
#  {'pattern': '14th_century-> john_f._kennedy', 'support': 6},
#  {'pattern': '14th_century-> united_states', 'support': 6},
#  {'pattern': '14th_century-> time', 'support': 6},
#  {'pattern': '14th_century-> time-> isaac_newton', 'support': 6},
#  {'pattern': '14th_century-> time-> isaac_newton-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> light', 'support': 6},
#  {'pattern': '14th_century-> time-> light-> color', 'support': 6},
#  {'pattern': '14th_century-> time-> light-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> light-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> color', 'support': 6},
#  {'pattern': '14th_century-> time-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> sunlight', 'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere-> ultraviolet',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere-> color',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> color', 'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> sunlight-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> sun', 'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere', 'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere-> ultraviolet',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere-> color',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> time-> sun-> ultraviolet-> color', 'support': 6},
#  {'pattern': '14th_century-> time-> sun-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> sun-> color', 'support': 6},
#  {'pattern': '14th_century-> time-> sun-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> sun-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere', 'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere-> ultraviolet',
#   'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere-> color',
#   'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> time-> ultraviolet-> color', 'support': 6},
#  {'pattern': '14th_century-> time-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> time-> ultraviolet-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> physics', 'support': 6},
#  {'pattern': '14th_century-> time-> physics-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> time-> speed_of_light', 'support': 6},
#  {'pattern': '14th_century-> time-> speed_of_light-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> isaac_newton', 'support': 6},
#  {'pattern': '14th_century-> isaac_newton-> color', 'support': 6},
#  {'pattern': '14th_century-> isaac_newton-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> isaac_newton-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> light', 'support': 6},
#  {'pattern': '14th_century-> light-> color', 'support': 6},
#  {'pattern': '14th_century-> light-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> light-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> color', 'support': 6},
#  {'pattern': '14th_century-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature', 'support': 6},
#  {'pattern': '14th_century-> nature-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> nature-> ultraviolet-> color', 'support': 6},
#  {'pattern': '14th_century-> nature-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> ultraviolet-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> ultraviolet-> light', 'support': 6},
#  {'pattern': '14th_century-> nature-> ultraviolet-> light-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> color', 'support': 6},
#  {'pattern': '14th_century-> nature-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> weather', 'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sunlight', 'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sunlight-> sun', 'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sunlight-> sun-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sunlight-> earth%27s_atmosphere',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sunlight-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sunlight-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sun', 'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> sun-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> earth%27s_atmosphere',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> weather-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> sunlight', 'support': 6},
#  {'pattern': '14th_century-> nature-> sunlight-> sun', 'support': 6},
#  {'pattern': '14th_century-> nature-> sunlight-> sun-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> sunlight-> earth%27s_atmosphere',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> sunlight-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> sunlight-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> sun', 'support': 6},
#  {'pattern': '14th_century-> nature-> sun-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere', 'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere-> ultraviolet',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere-> ultraviolet-> light',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere-> ultraviolet-> light-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere-> light',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere-> light-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> nature-> light', 'support': 6},
#  {'pattern': '14th_century-> nature-> light-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> ultraviolet-> color', 'support': 6},
#  {'pattern': '14th_century-> ultraviolet-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> ultraviolet-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> ultraviolet-> light', 'support': 6},
#  {'pattern': '14th_century-> ultraviolet-> light-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> science', 'support': 6},
#  {'pattern': '14th_century-> science-> color', 'support': 6},
#  {'pattern': '14th_century-> science-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> science-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> science-> physics', 'support': 6},
#  {'pattern': '14th_century-> science-> physics-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> weather', 'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight', 'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> sun', 'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> sun-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> earth%27s_atmosphere',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> color', 'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> sunlight-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> weather-> sun', 'support': 6},
#  {'pattern': '14th_century-> weather-> sun-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> weather-> earth%27s_atmosphere', 'support': 6},
#  {'pattern': '14th_century-> weather-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> weather-> ultraviolet-> color', 'support': 6},
#  {'pattern': '14th_century-> weather-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> weather-> ultraviolet-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> weather-> color', 'support': 6},
#  {'pattern': '14th_century-> weather-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> weather-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sunlight', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> sun', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> sun-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere-> ultraviolet',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere-> color',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> ultraviolet-> color', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sunlight-> ultraviolet-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> color', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sunlight-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sun', 'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere', 'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere-> ultraviolet',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere-> color',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> earth%27s_atmosphere-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> ultraviolet', 'support': 6},
#  {'pattern': '14th_century-> sun-> ultraviolet-> color', 'support': 6},
#  {'pattern': '14th_century-> sun-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> sun-> ultraviolet-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sun-> color', 'support': 6},
#  {'pattern': '14th_century-> sun-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sun-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere', 'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> ultraviolet',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> ultraviolet-> color',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> ultraviolet-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> ultraviolet-> light',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> ultraviolet-> light-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> ultraviolet-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> color', 'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> color-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> light', 'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> light-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> earth%27s_atmosphere-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> christianity', 'support': 6},
#  {'pattern': '14th_century-> christianity-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> rain', 'support': 6},
#  {'pattern': '14th_century-> rain-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> rain-> cloud', 'support': 6},
#  {'pattern': '14th_century-> rain-> cloud-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> leonardo_da_vinci', 'support': 6},
#  {'pattern': '14th_century-> leonardo_da_vinci-> water', 'support': 6},
#  {'pattern': '14th_century-> leonardo_da_vinci-> water-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> leonardo_da_vinci-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> water', 'support': 6},
#  {'pattern': '14th_century-> water-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> cloud', 'support': 6},
#  {'pattern': '14th_century-> cloud-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> physics', 'support': 6},
#  {'pattern': '14th_century-> physics-> speed_of_light', 'support': 6},
#  {'pattern': '14th_century-> physics-> speed_of_light-> rainbow',
#   'support': 6},
#  {'pattern': '14th_century-> physics-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> physics-> color', 'support': 6},
#  {'pattern': '14th_century-> physics-> color-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> speed_of_light', 'support': 6},
#  {'pattern': '14th_century-> speed_of_light-> rainbow', 'support': 6},
#  {'pattern': '14th_century-> sodium', 'support': 6},
#  {'pattern': '14th_century-> england', 'support': 6},
#  {'pattern': '14th_century-> england-> elizabeth_i_of_england', 'support': 6},
#  {'pattern': '14th_century-> 13th_century', 'support': 6},
#  {'pattern': '14th_century-> elizabeth_i_of_england', 'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war', 'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england-> wars_of_the_roses',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england-> wars_of_the_roses-> henry_viii_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england-> wars_of_the_roses-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england-> wars_of_the_roses-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england-> henry_viii_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_vi_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> wars_of_the_roses',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> wars_of_the_roses-> henry_viii_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> wars_of_the_roses-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> wars_of_the_roses-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_viii_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> hundred_years%27_war-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england', 'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england-> wars_of_the_roses',
#   'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england-> wars_of_the_roses-> henry_viii_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england-> wars_of_the_roses-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england-> wars_of_the_roses-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england-> henry_viii_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> henry_vi_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> wars_of_the_roses', 'support': 6},
#  {'pattern': '14th_century-> wars_of_the_roses-> henry_viii_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> wars_of_the_roses-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> wars_of_the_roses-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '14th_century-> henry_viii_of_england', 'support': 6},
#  {'pattern': '14th_century-> henry_viii_of_england-> elizabeth_i_of_england',
#   'support': 6},
#  {'pattern': '15th_century', 'support': 21},
#  {'pattern': '15th_century-> 16th_century', 'support': 12},
#  {'pattern': '15th_century-> 13th_century', 'support': 6},
#  {'pattern': '16th_century', 'support': 21},
#  {'pattern': 'pacific_ocean', 'support': 21},
#  {'pattern': 'pacific_ocean-> atlantic_ocean', 'support': 6},
#  {'pattern': 'pacific_ocean-> water', 'support': 6},
#  {'pattern': 'pacific_ocean-> ocean', 'support': 6},
#  {'pattern': 'pacific_ocean-> animal', 'support': 6},
#  {'pattern': 'pacific_ocean-> animal-> mammal', 'support': 6},
#  {'pattern': 'pacific_ocean-> mammal', 'support': 6},
#  {'pattern': 'pacific_ocean-> south_china_sea', 'support': 6},
#  {'pattern': 'atlantic_ocean', 'support': 21},
#  {'pattern': 'atlantic_ocean-> africa', 'support': 17},
#  {'pattern': 'atlantic_ocean-> africa-> democratic_republic_of_the_congo',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> africa-> democratic_republic_of_the_congo-> second_congo_war',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> africa-> second_congo_war', 'support': 6},
#  {'pattern': 'atlantic_ocean-> ocean', 'support': 17},
#  {'pattern': 'atlantic_ocean-> ocean-> shark', 'support': 6},
#  {'pattern': 'atlantic_ocean-> ocean-> shark-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> ocean-> great_white_shark', 'support': 6},
#  {'pattern': 'atlantic_ocean-> tropical_cyclone', 'support': 9},
#  {'pattern': 'atlantic_ocean-> tropical_cyclone-> hurricane_katrina',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> sun', 'support': 9},
#  {'pattern': 'atlantic_ocean-> fish', 'support': 9},
#  {'pattern': 'atlantic_ocean-> fish-> whale_shark', 'support': 9},
#  {'pattern': 'atlantic_ocean-> fish-> whale_shark-> shark', 'support': 9},
#  {'pattern': 'atlantic_ocean-> fish-> whale_shark-> shark-> great_white_shark',
#   'support': 9},
#  {'pattern': 'atlantic_ocean-> fish-> whale_shark-> great_white_shark',
#   'support': 9},
#  {'pattern': 'atlantic_ocean-> fish-> shark', 'support': 9},
#  {'pattern': 'atlantic_ocean-> fish-> shark-> great_white_shark',
#   'support': 9},
#  {'pattern': 'atlantic_ocean-> fish-> great_white_shark', 'support': 9},
#  {'pattern': 'atlantic_ocean-> whale', 'support': 8},
#  {'pattern': 'atlantic_ocean-> whale-> fish', 'support': 8},
#  {'pattern': 'atlantic_ocean-> whale-> fish-> whale_shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> whale-> fish-> whale_shark-> shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> fish-> whale_shark-> shark-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> fish-> whale_shark-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> fish-> shark', 'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> fish-> shark-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> fish-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> whale_shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> whale-> whale_shark-> shark', 'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> whale_shark-> shark-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> whale_shark-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> shark', 'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> shark-> great_white_shark',
#   'support': 6},
#  {'pattern': 'atlantic_ocean-> whale-> great_white_shark', 'support': 6},
#  {'pattern': 'atlantic_ocean-> whale_shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> whale_shark-> shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> whale_shark-> shark-> great_white_shark',
#   'support': 8},
#  {'pattern': 'atlantic_ocean-> whale_shark-> great_white_shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> shark-> great_white_shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> great_white_shark', 'support': 8},
#  {'pattern': 'atlantic_ocean-> pacific_ocean', 'support': 6},
#  {'pattern': 'atlantic_ocean-> orca', 'support': 5},
#  {'pattern': 'atlantic_ocean-> orca-> shark', 'support': 5},
#  {'pattern': 'atlantic_ocean-> dolphin', 'support': 5},
#  {'pattern': 'atlantic_ocean-> dolphin-> shark', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_kingdom', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_kingdom-> england', 'support': 5},
#  {'pattern': 'atlantic_ocean-> england', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> plant', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> plant-> tree', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> plant-> tree-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> plant-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> tree', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> tree-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> earth-> sun', 'support': 5},
#  {'pattern': 'atlantic_ocean-> hurricane_katrina', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> moon', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> moon-> neil_armstrong',
#   'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> neil_armstrong', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> tree', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> tree-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> wheat', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> wheat-> seed', 'support': 5},
#  {'pattern': 'atlantic_ocean-> united_states-> seed', 'support': 5},
#  {'pattern': 'atlantic_ocean-> north_america', 'support': 5},
#  {'pattern': 'atlantic_ocean-> moon', 'support': 5},
#  {'pattern': 'atlantic_ocean-> moon-> neil_armstrong', 'support': 5},
#  {'pattern': 'atlantic_ocean-> neil_armstrong', 'support': 5},
#  {'pattern': 'atlantic_ocean-> canada', 'support': 5},
#  {'pattern': 'atlantic_ocean-> democratic_republic_of_the_congo',
#   'support': 5},
#  {'pattern': 'atlantic_ocean-> democratic_republic_of_the_congo-> second_congo_war',
#   'support': 5},
#  {'pattern': 'atlantic_ocean-> second_congo_war', 'support': 5},
#  {'pattern': 'atlantic_ocean-> anglicanism', 'support': 5},
#  {'pattern': 'atlantic_ocean-> anglicanism-> anglican_communion',
#   'support': 5},
#  {'pattern': 'atlantic_ocean-> anglican_communion', 'support': 5},
#  {'pattern': 'atlantic_ocean-> italy', 'support': 5},
#  {'pattern': 'atlantic_ocean-> norway', 'support': 5},
#  {'pattern': 'atlantic_ocean-> plant', 'support': 5},
#  {'pattern': 'atlantic_ocean-> plant-> tree', 'support': 5},
#  {'pattern': 'atlantic_ocean-> plant-> tree-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> plant-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> tree', 'support': 5},
#  {'pattern': 'atlantic_ocean-> tree-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> wood', 'support': 5},
#  {'pattern': 'atlantic_ocean-> forest', 'support': 5},
#  {'pattern': 'atlantic_ocean-> brazil', 'support': 5},
#  {'pattern': 'atlantic_ocean-> brazil-> rainforest', 'support': 5},
#  {'pattern': 'atlantic_ocean-> rainforest', 'support': 5},
#  {'pattern': 'atlantic_ocean-> seed', 'support': 5},
#  {'pattern': 'atlantic_ocean-> wheat', 'support': 5},
#  {'pattern': 'atlantic_ocean-> wheat-> seed', 'support': 5},
#  {'pattern': 'africa', 'support': 21},
#  {'pattern': 'africa-> atlantic_slave_trade', 'support': 15},
#  {'pattern': 'africa-> atlantic_slave_trade-> african_slave_trade',
#   'support': 9},
#  {'pattern': 'africa-> atlantic_slave_trade-> united_states', 'support': 6},
#  {'pattern': 'africa-> atlantic_slave_trade-> united_states-> american_civil_war',
#   'support': 6},
#  {'pattern': 'africa-> atlantic_slave_trade-> american_civil_war',
#   'support': 6},
#  {'pattern': 'africa-> african_slave_trade', 'support': 9},
#  {'pattern': 'africa-> burundi', 'support': 5},
#  {'pattern': 'africa-> gold', 'support': 5},
#  {'pattern': 'africa-> crocodile', 'support': 5},
#  {'pattern': 'africa-> lion', 'support': 5},
#  {'pattern': 'africa-> lion-> antelope', 'support': 5},
#  {'pattern': 'africa-> antelope', 'support': 5},
#  {'pattern': 'africa-> elephant', 'support': 5},
#  {'pattern': 'africa-> elephant-> ivory', 'support': 5},
#  {'pattern': 'africa-> ivory', 'support': 5},
#  {'pattern': 'africa-> kenya', 'support': 5},
#  {'pattern': 'africa-> kenya-> elephant', 'support': 5},
#  {'pattern': 'africa-> egypt', 'support': 5},
#  {'pattern': 'africa-> egypt-> united_kingdom', 'support': 5},
#  {'pattern': 'africa-> egypt-> united_kingdom-> england', 'support': 5},
#  {'pattern': 'africa-> egypt-> england', 'support': 5},
#  {'pattern': 'africa-> egypt-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> egypt-> egyptian_pyramids', 'support': 5},
#  {'pattern': 'africa-> egypt-> egyptian_pyramids-> pyramid', 'support': 5},
#  {'pattern': 'africa-> egypt-> pyramid', 'support': 5},
#  {'pattern': 'africa-> hiv', 'support': 5},
#  {'pattern': 'africa-> hiv-> aids', 'support': 5},
#  {'pattern': 'africa-> aids', 'support': 5},
#  {'pattern': 'africa-> europe', 'support': 5},
#  {'pattern': 'africa-> europe-> united_kingdom', 'support': 5},
#  {'pattern': 'africa-> europe-> united_kingdom-> england', 'support': 5},
#  {'pattern': 'africa-> europe-> united_kingdom-> london', 'support': 5},
#  {'pattern': 'africa-> europe-> united_kingdom-> london-> hampstead_heath',
#   'support': 5},
#  {'pattern': 'africa-> europe-> united_kingdom-> hampstead_heath',
#   'support': 5},
#  {'pattern': 'africa-> europe-> england', 'support': 5},
#  {'pattern': 'africa-> europe-> great_britain', 'support': 5},
#  {'pattern': 'africa-> europe-> great_britain-> england', 'support': 5},
#  {'pattern': 'africa-> europe-> london', 'support': 5},
#  {'pattern': 'africa-> europe-> london-> hampstead_heath', 'support': 5},
#  {'pattern': 'africa-> europe-> hampstead_heath', 'support': 5},
#  {'pattern': 'africa-> united_kingdom', 'support': 5},
#  {'pattern': 'africa-> united_kingdom-> england', 'support': 5},
#  {'pattern': 'africa-> united_kingdom-> london', 'support': 5},
#  {'pattern': 'africa-> united_kingdom-> london-> hampstead_heath',
#   'support': 5},
#  {'pattern': 'africa-> united_kingdom-> hampstead_heath', 'support': 5},
#  {'pattern': 'africa-> england', 'support': 5},
#  {'pattern': 'africa-> scramble_for_africa', 'support': 5},
#  {'pattern': 'africa-> scramble_for_africa-> england', 'support': 5},
#  {'pattern': 'africa-> continent', 'support': 5},
#  {'pattern': 'africa-> continent-> europe', 'support': 5},
#  {'pattern': 'africa-> continent-> europe-> united_kingdom', 'support': 5},
#  {'pattern': 'africa-> continent-> europe-> united_kingdom-> england',
#   'support': 5},
#  {'pattern': 'africa-> continent-> europe-> england', 'support': 5},
#  {'pattern': 'africa-> continent-> united_kingdom', 'support': 5},
#  {'pattern': 'africa-> continent-> united_kingdom-> england', 'support': 5},
#  {'pattern': 'africa-> continent-> england', 'support': 5},
#  {'pattern': 'africa-> continent-> british_isles', 'support': 5},
#  {'pattern': 'africa-> continent-> british_isles-> england', 'support': 5},
#  {'pattern': 'africa-> continent-> north_america', 'support': 5},
#  {'pattern': 'africa-> continent-> earth', 'support': 5},
#  {'pattern': 'africa-> continent-> earth-> sun', 'support': 5},
#  {'pattern': 'africa-> continent-> sun', 'support': 5},
#  {'pattern': 'africa-> european_union', 'support': 5},
#  {'pattern': 'africa-> great_britain', 'support': 5},
#  {'pattern': 'africa-> great_britain-> england', 'support': 5},
#  {'pattern': 'africa-> world_war_ii', 'support': 5},
#  {'pattern': 'africa-> world_war_ii-> united_kingdom', 'support': 5},
#  {'pattern': 'africa-> world_war_ii-> united_kingdom-> england', 'support': 5},
#  {'pattern': 'africa-> world_war_ii-> england', 'support': 5},
#  {'pattern': 'africa-> british_isles', 'support': 5},
#  {'pattern': 'africa-> british_isles-> london', 'support': 5},
#  {'pattern': 'africa-> british_isles-> england', 'support': 5},
#  {'pattern': 'africa-> british_isles-> united_kingdom', 'support': 5},
#  {'pattern': 'africa-> british_isles-> united_kingdom-> england',
#   'support': 5},
#  {'pattern': 'africa-> london', 'support': 5},
#  {'pattern': 'africa-> london-> hampstead_heath', 'support': 5},
#  {'pattern': 'africa-> english_language', 'support': 5},
#  {'pattern': 'africa-> english_language-> england', 'support': 5},
#  {'pattern': 'africa-> earth', 'support': 5},
#  {'pattern': 'africa-> earth-> europe', 'support': 5},
#  {'pattern': 'africa-> earth-> europe-> england', 'support': 5},
#  {'pattern': 'africa-> earth-> england', 'support': 5},
#  {'pattern': 'africa-> earth-> solar_system', 'support': 5},
#  {'pattern': 'africa-> earth-> sun', 'support': 5},
#  {'pattern': 'africa-> language', 'support': 5},
#  {'pattern': 'africa-> language-> english_language', 'support': 5},
#  {'pattern': 'africa-> ethiopia', 'support': 5},
#  {'pattern': 'africa-> north_america', 'support': 5},
#  {'pattern': 'africa-> united_states', 'support': 5},
#  {'pattern': 'africa-> united_states-> potato', 'support': 5},
#  {'pattern': 'africa-> united_states-> american_civil_war', 'support': 5},
#  {'pattern': 'africa-> potato', 'support': 5},
#  {'pattern': 'africa-> fruit', 'support': 5},
#  {'pattern': 'africa-> fruit-> mango', 'support': 5},
#  {'pattern': 'africa-> vegetable', 'support': 5},
#  {'pattern': 'africa-> vegetable-> potato', 'support': 5},
#  {'pattern': 'africa-> rice', 'support': 5},
#  {'pattern': 'africa-> rice-> potato', 'support': 5},
#  {'pattern': 'africa-> plant', 'support': 5},
#  {'pattern': 'africa-> solar_system', 'support': 5},
#  {'pattern': 'africa-> asia', 'support': 5},
#  {'pattern': 'africa-> asia-> japan', 'support': 5},
#  {'pattern': 'africa-> asia-> cambodia', 'support': 5},
#  {'pattern': 'africa-> sun', 'support': 5},
#  {'pattern': 'africa-> australia', 'support': 5},
#  {'pattern': 'africa-> rainforest', 'support': 5},
#  {'pattern': 'africa-> rainforest-> bird', 'support': 5},
#  {'pattern': 'africa-> rainforest-> bird-> parrot', 'support': 5},
#  {'pattern': 'africa-> rainforest-> parrot', 'support': 5},
#  {'pattern': 'africa-> tropics', 'support': 5},
#  {'pattern': 'africa-> temperate', 'support': 5},
#  {'pattern': 'africa-> periodic_table', 'support': 5},
#  {'pattern': 'africa-> periodic_table-> americium', 'support': 5},
#  {'pattern': 'africa-> americium', 'support': 5},
#  {'pattern': 'africa-> age_of_enlightenment', 'support': 5},
#  {'pattern': 'africa-> age_of_enlightenment-> differential_equation',
#   'support': 5},
#  {'pattern': 'africa-> physics', 'support': 5},
#  {'pattern': 'africa-> physics-> mathematics', 'support': 5},
#  {'pattern': 'africa-> physics-> mathematics-> differential_equation',
#   'support': 5},
#  {'pattern': 'africa-> physics-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> mathematics', 'support': 5},
#  {'pattern': 'africa-> mathematics-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> human', 'support': 5},
#  {'pattern': 'africa-> human-> science', 'support': 5},
#  {'pattern': 'africa-> human-> science-> mathematics', 'support': 5},
#  {'pattern': 'africa-> human-> science-> mathematics-> differential_equation',
#   'support': 5},
#  {'pattern': 'africa-> human-> science-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> human-> mathematics', 'support': 5},
#  {'pattern': 'africa-> human-> mathematics-> differential_equation',
#   'support': 5},
#  {'pattern': 'africa-> human-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> human-> brain', 'support': 5},
#  {'pattern': 'africa-> human-> brain-> sleep', 'support': 5},
#  {'pattern': 'africa-> human-> sleep', 'support': 5},
#  {'pattern': 'africa-> science', 'support': 5},
#  {'pattern': 'africa-> science-> mathematics', 'support': 5},
#  {'pattern': 'africa-> science-> mathematics-> differential_equation',
#   'support': 5},
#  {'pattern': 'africa-> science-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> calculus', 'support': 5},
#  {'pattern': 'africa-> calculus-> differential_equation', 'support': 5},
#  {'pattern': 'africa-> ancient_egypt', 'support': 5},
#  {'pattern': 'africa-> hampstead_heath', 'support': 5},
#  {'pattern': 'africa-> japan', 'support': 5},
#  {'pattern': 'africa-> brain', 'support': 5},
#  {'pattern': 'africa-> brain-> sleep', 'support': 5},
#  {'pattern': 'africa-> sleep', 'support': 5},
#  {'pattern': 'africa-> mind', 'support': 5},
#  {'pattern': 'africa-> mind-> psychology', 'support': 5},
#  {'pattern': 'africa-> mind-> psychology-> brain', 'support': 5},
#  {'pattern': 'africa-> mind-> psychology-> brain-> sleep', 'support': 5},
#  {'pattern': 'africa-> mind-> psychology-> sleep', 'support': 5},
#  {'pattern': 'africa-> mind-> brain', 'support': 5},
#  {'pattern': 'africa-> mind-> brain-> sleep', 'support': 5},
#  {'pattern': 'africa-> mind-> sleep', 'support': 5},
#  {'pattern': 'africa-> psychology', 'support': 5},
#  {'pattern': 'africa-> psychology-> brain', 'support': 5},
#  {'pattern': 'africa-> psychology-> brain-> sleep', 'support': 5},
#  {'pattern': 'africa-> psychology-> sleep', 'support': 5},
#  {'pattern': 'africa-> jesus', 'support': 5},
#  {'pattern': 'africa-> christianity', 'support': 5},
#  {'pattern': 'africa-> christianity-> jesus', 'support': 5},
#  {'pattern': 'africa-> jazz', 'support': 5},
#  {'pattern': 'africa-> giraffe', 'support': 5},
#  {'pattern': 'africa-> giraffe-> okapi', 'support': 5},
#  {'pattern': 'africa-> giraffe-> okapi-> zebra', 'support': 5},
#  {'pattern': 'africa-> giraffe-> okapi-> zebra-> gazelle', 'support': 5},
#  {'pattern': 'africa-> giraffe-> okapi-> gazelle', 'support': 5},
#  {'pattern': 'africa-> giraffe-> zebra', 'support': 5},
#  {'pattern': 'africa-> giraffe-> zebra-> gazelle', 'support': 5},
#  {'pattern': 'africa-> giraffe-> gazelle', 'support': 5},
#  {'pattern': 'africa-> animal', 'support': 5},
#  {'pattern': 'africa-> bird', 'support': 5},
#  {'pattern': 'africa-> bird-> parrot', 'support': 5},
#  {'pattern': 'africa-> parrot', 'support': 5},
#  {'pattern': 'africa-> sudan', 'support': 5},
#  {'pattern': 'africa-> african_union', 'support': 5},
#  {'pattern': 'africa-> herbivore', 'support': 5},
#  {'pattern': 'africa-> herbivore-> lion', 'support': 5},
#  {'pattern': 'africa-> herbivore-> zebra', 'support': 5},
#  {'pattern': 'africa-> zebra', 'support': 5},
#  {'pattern': 'africa-> zebra-> gazelle', 'support': 5},
#  {'pattern': 'africa-> american_civil_war', 'support': 5},
#  {'pattern': 'africa-> cambodia', 'support': 5},
#  {'pattern': 'africa-> mango', 'support': 5},
#  {'pattern': 'africa-> democratic_republic_of_the_congo', 'support': 5},
#  {'pattern': 'africa-> democratic_republic_of_the_congo-> second_congo_war',
#   'support': 5},
#  {'pattern': 'africa-> second_congo_war', 'support': 5},
#  {'pattern': 'africa-> egyptian_pyramids', 'support': 5},
#  {'pattern': 'africa-> egyptian_pyramids-> pyramid', 'support': 5},
#  {'pattern': 'africa-> pyramid', 'support': 5},
#  {'pattern': 'africa-> okapi', 'support': 5},
#  {'pattern': 'africa-> okapi-> zebra', 'support': 5},
#  {'pattern': 'africa-> okapi-> zebra-> gazelle', 'support': 5},
#  {'pattern': 'africa-> okapi-> gazelle', 'support': 5},
#  {'pattern': 'africa-> gazelle', 'support': 5},
#  {'pattern': 'africa-> cheetah', 'support': 5},
#  {'pattern': 'africa-> cheetah-> gazelle', 'support': 5},
#  {'pattern': 'atlantic_slave_trade', 'support': 21},
#  {'pattern': 'atlantic_slave_trade-> african_slave_trade', 'support': 12},
#  {'pattern': 'atlantic_slave_trade-> united_states', 'support': 12},
#  {'pattern': 'atlantic_slave_trade-> united_states-> american_civil_war',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> american_civil_war', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> sugar', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> brazil', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> australia', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> plant', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> plant-> nitrogen_fixation', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> fossil_fuel', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> continent', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> continent-> north_america', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> continent-> europe', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> north_america', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> uranium', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> industrial_revolution', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> industrial_revolution-> communism',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> mining', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> mining-> uranium', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> mexico', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> mexico-> aztec', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> mexico-> maya_civilization',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> aztec', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> aztec-> 13th_century', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> aztec-> 14th_century', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> aztec-> 14th_century-> 13th_century',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> maya_civilization', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> 13th_century', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> 15th_century', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> 15th_century-> 13th_century',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> 14th_century', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> 14th_century-> 13th_century',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> europe', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> finance', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> finance-> corporate_finance',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> finance-> corporate_finance-> investment_banking',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> finance-> investment_banking',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> corporate_finance', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> corporate_finance-> investment_banking',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> investment_banking', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> cotton', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> cotton-> plant', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> cotton-> plant-> nitrogen_fixation',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> cotton-> nitrogen_fixation',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> communism', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> nitrogen', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> nitrogen-> nitrogen_fixation',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> nitrogen_fixation', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> poland', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> poland-> marie_curie', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> poland-> marie_curie-> polonium',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> poland-> polonium', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> marie_curie', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> marie_curie-> polonium', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> polonium', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> dinosaur', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> dinosaur-> pterosaur', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> pterosaur', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> insect', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> insect-> spider', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> insect-> spider-> trapdoor_spider',
#   'support': 6},
#  {'pattern': 'atlantic_slave_trade-> insect-> trapdoor_spider', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> spider', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> spider-> trapdoor_spider', 'support': 6},
#  {'pattern': 'atlantic_slave_trade-> trapdoor_spider', 'support': 6},
#  {'pattern': 'african_slave_trade', 'support': 12},
#  {'pattern': 'europe', 'support': 12},
#  {'pattern': 'europe-> africa', 'support': 12},
#  {'pattern': 'europe-> africa-> elephant', 'support': 9},
#  {'pattern': 'europe-> africa-> elephant-> ivory', 'support': 9},
#  {'pattern': 'europe-> africa-> ivory', 'support': 9},
#  {'pattern': 'europe-> north_america', 'support': 6},
#  {'pattern': 'europe-> united_states', 'support': 6},
#  {'pattern': 'europe-> united_states-> spain', 'support': 5},
#  {'pattern': 'europe-> republic_of_ireland', 'support': 6},
#  {'pattern': 'europe-> europe', 'support': 6},
#  {'pattern': 'europe-> time', 'support': 6},
#  {'pattern': 'europe-> physics', 'support': 6},
#  {'pattern': 'europe-> england', 'support': 6},
#  {'pattern': 'europe-> england-> london', 'support': 6},
#  {'pattern': 'europe-> christianity', 'support': 5},
#  {'pattern': 'europe-> sweden', 'support': 5},
#  {'pattern': 'europe-> mammal', 'support': 5},
#  {'pattern': 'europe-> mammal-> elephant', 'support': 5},
#  {'pattern': 'europe-> mammal-> elephant-> ivory', 'support': 5},
#  {'pattern': 'europe-> mammal-> ivory', 'support': 5},
#  {'pattern': 'europe-> paris', 'support': 5},
#  {'pattern': 'europe-> iceland', 'support': 5},
#  {'pattern': 'europe-> iceland-> surtsey', 'support': 5},
#  {'pattern': 'europe-> surtsey', 'support': 5},
#  {'pattern': 'europe-> united_kingdom', 'support': 5},
#  {'pattern': 'europe-> united_kingdom-> england', 'support': 5},
#  {'pattern': 'europe-> united_kingdom-> england-> london', 'support': 5},
#  {'pattern': 'europe-> united_kingdom-> london', 'support': 5},
# ...
#  {'pattern': 'british_empire-> united_states-> vietnam_war', 'support': 6},
#  {'pattern': 'british_empire-> united_states-> vietnam_war-> vietnam',
#   'support': 6},
#  {'pattern': 'british_empire-> united_states-> vietnam', 'support': 6},
#  {'pattern': 'british_empire-> vietnam_war', 'support': 6},
#  {'pattern': 'british_empire-> vietnam_war-> vietnam', 'support': 6},
#  {'pattern': 'british_empire-> vietnam', 'support': 6},
#  {'pattern': 'british_empire-> north_america', 'support': 6},
#  {'pattern': 'slavery', 'support': 6},
#  {'pattern': 'slavery-> africa', 'support': 6},
#  {'pattern': 'slavery-> herbivore', 'support': 6},
#  {'pattern': 'slavery-> virus', 'support': 6},
#  {'pattern': 'slavery-> bacteria', 'support': 6},
#  {'pattern': 'slavery-> bacteria-> virus', 'support': 6},
#  {'pattern': 'slavery-> poverty', 'support': 6},
#  {'pattern': 'slavery-> poverty-> tuberculosis', 'support': 6},
#  {'pattern': 'slavery-> poverty-> tuberculosis-> virus', 'support': 6},
#  {'pattern': 'slavery-> poverty-> virus', 'support': 6},
#  {'pattern': 'slavery-> tuberculosis', 'support': 6},
#  {'pattern': 'slavery-> tuberculosis-> virus', 'support': 6},
#  {'pattern': 'renaissance', 'support': 6},
#  {'pattern': 'renaissance-> rain', 'support': 6},
#  {'pattern': 'renaissance-> rain-> rainbow', 'support': 6},
#  {'pattern': 'renaissance-> isaac_newton', 'support': 6},
#  {'pattern': 'renaissance-> isaac_newton-> rainbow', 'support': 6},
#  {'pattern': 'renaissance-> rainbow', 'support': 6},
#  {'pattern': 'renaissance-> leonardo_da_vinci', 'support': 6},
#  {'pattern': 'renaissance-> leonardo_da_vinci-> water', 'support': 6},
#  {'pattern': 'renaissance-> leonardo_da_vinci-> water-> rainbow',
#   'support': 6},
#  {'pattern': 'renaissance-> leonardo_da_vinci-> rainbow', 'support': 6},
#  {'pattern': 'renaissance-> water', 'support': 6},
#  {'pattern': 'renaissance-> water-> rainbow', 'support': 6},
#  {'pattern': 'renaissance-> art', 'support': 6},
#  {'pattern': 'renaissance-> color', 'support': 6},
#  {'pattern': 'renaissance-> color-> rainbow', 'support': 6},
#  {'pattern': 'renaissance-> science', 'support': 6},
#  {'pattern': 'renaissance-> philosophy', 'support': 6},
#  {'pattern': 'ancient_greece', 'support': 6},
#  {'pattern': 'ancient_greece-> europe', 'support': 6},
#  {'pattern': 'ancient_greece-> europe-> united_kingdom', 'support': 6},
#  {'pattern': 'ancient_greece-> united_kingdom', 'support': 6},
#  {'pattern': 'ancient_greece-> egypt', 'support': 6},
#  {'pattern': 'ancient_greece-> black_sea', 'support': 6},
#  {'pattern': 'ancient_greece-> atlantic_ocean', 'support': 6},
#  {'pattern': 'ancient_greece-> atlantic_ocean-> ocean', 'support': 6},
#  {'pattern': 'ancient_greece-> ocean', 'support': 6},
#  {'pattern': 'ancient_greece-> roman_empire', 'support': 6},
#  {'pattern': 'ancient_greece-> mathematics', 'support': 6},
#  {'pattern': 'ancient_greece-> arithmetic', 'support': 6},
#  {'pattern': 'ancient_greece-> science', 'support': 6},
#  {'pattern': 'ancient_greece-> science-> physics', 'support': 6},
#  {'pattern': 'ancient_greece-> science-> physics-> albert_einstein',
#   'support': 6},
#  {'pattern': 'ancient_greece-> science-> albert_einstein', 'support': 6},
#  {'pattern': 'ancient_greece-> physics', 'support': 6},
#  {'pattern': 'ancient_greece-> physics-> albert_einstein', 'support': 6},
#  {'pattern': 'ancient_greece-> albert_einstein', 'support': 6},
#  {'pattern': 'ancient_greece-> lemon', 'support': 6},
#  {'pattern': 'ancient_greece-> lemon-> lemon_balm', 'support': 6},
#  {'pattern': 'ancient_greece-> lemon_balm', 'support': 6},
#  {'pattern': 'ancient_greece-> agriculture', 'support': 6},
#  {'pattern': 'ancient_greece-> parthenon', 'support': 6},
#  {'pattern': 'greece', 'support': 6},
#  {'pattern': 'greece-> africa', 'support': 6},
#  {'pattern': 'greece-> ocean', 'support': 6},
#  {'pattern': 'greece-> water', 'support': 6},
#  {'pattern': 'greece-> water-> ocean', 'support': 6},
#  {'pattern': 'greece-> mathematics', 'support': 6},
#  {'pattern': 'italy', 'support': 6},
#  {'pattern': 'italy-> roman_catholic_church', 'support': 6},
#  {'pattern': 'italy-> france', 'support': 6},
#  {'pattern': 'italy-> jesus', 'support': 6},
#  {'pattern': 'italy-> christianity', 'support': 6},
#  {'pattern': 'italy-> benito_mussolini', 'support': 5},
#  {'pattern': 'italy-> agriculture', 'support': 5},
#  {'pattern': 'italy-> agriculture-> food', 'support': 5},
#  {'pattern': 'italy-> food', 'support': 5},
#  {'pattern': 'roman_catholic_church', 'support': 6},
#  {'pattern': 'roman_catholic_church-> physics', 'support': 5},
#  {'pattern': 'roman_catholic_church-> jesus', 'support': 5},
#  {'pattern': 'roman_catholic_church-> jesus-> bible', 'support': 5},
#  {'pattern': 'roman_catholic_church-> pope_john_paul_ii', 'support': 5},
#  {'pattern': 'roman_catholic_church-> christianity', 'support': 5},
#  {'pattern': 'roman_catholic_church-> christianity-> agnosticism',
#   'support': 5},
#  {'pattern': 'roman_catholic_church-> christianity-> jesus', 'support': 5},
#  {'pattern': 'roman_catholic_church-> agnosticism', 'support': 5},
#  {'pattern': 'roman_catholic_church-> eastern_orthodox_church', 'support': 5},
#  {'pattern': 'roman_catholic_church-> god', 'support': 5},
#  {'pattern': 'roman_catholic_church-> bible', 'support': 5},
#  {'pattern': 'roman_catholic_church-> bible-> united_states', 'support': 5},
#  {'pattern': 'roman_catholic_church-> united_states', 'support': 5},
#  {'pattern': 'roman_catholic_church-> asia', 'support': 5},
#  {'pattern': 'hiv', 'support': 6},
#  {'pattern': 'hiv-> aids', 'support': 6},
#  {'pattern': 'hiv-> human', 'support': 6},
#  {'pattern': 'president_of_the_united_states', 'support': 6},
#  {'pattern': 'president_of_the_united_states-> john_f._kennedy', 'support': 6},
#  {'pattern': 'president_of_the_united_states-> william_mckinley',
#   'support': 6},
#  {'pattern': 'president_of_the_united_states-> chester_a._arthur',
#   'support': 6},
#  {'pattern': 'president_of_the_united_states-> james_monroe', 'support': 6},
#  {'pattern': 'president_of_the_united_states-> harry_s._truman', 'support': 6},
#  {'pattern': 'president_of_the_united_states-> bill_clinton', 'support': 6},
#  {'pattern': 'john_f._kennedy', 'support': 6},
#  {'pattern': 'north_america', 'support': 6},
#  {'pattern': 'north_america-> united_states', 'support': 6},
#  {'pattern': 'north_america-> united_states-> president_of_the_united_states',
#   'support': 5},
#  {'pattern': 'north_america-> president_of_the_united_states', 'support': 5},
#  {'pattern': 'north_america-> south_america', 'support': 5},
#  {'pattern': 'north_america-> south_america-> amazon_rainforest',
#   'support': 5},
#  {'pattern': 'north_america-> south_america-> amazon_rainforest-> bird',
#   'support': 5},
#  {'pattern': 'north_america-> south_america-> amazon_rainforest-> bird-> parrot',
#   'support': 5},
#  {'pattern': 'north_america-> south_america-> amazon_rainforest-> parrot',
#   'support': 5},
#  {'pattern': 'north_america-> south_america-> bird', 'support': 5},
#  {'pattern': 'north_america-> south_america-> bird-> parrot', 'support': 5},
#  {'pattern': 'north_america-> south_america-> parrot', 'support': 5},
#  {'pattern': 'north_america-> south_america-> ecuador', 'support': 5},
#  {'pattern': 'north_america-> amazon_rainforest', 'support': 5},
#  {'pattern': 'north_america-> amazon_rainforest-> bird', 'support': 5},
#  {'pattern': 'north_america-> amazon_rainforest-> bird-> parrot',
#   'support': 5},
#  {'pattern': 'north_america-> amazon_rainforest-> parrot', 'support': 5},
#  {'pattern': 'north_america-> bird', 'support': 5},
#  {'pattern': 'north_america-> bird-> parrot', 'support': 5},
#  {'pattern': 'north_america-> parrot', 'support': 5},
#  {'pattern': 'north_america-> continent', 'support': 5},
#  {'pattern': 'north_america-> continent-> africa', 'support': 5},
#  {'pattern': 'north_america-> asia', 'support': 5},
#  {'pattern': 'north_america-> hurricane_katrina', 'support': 5},
#  {'pattern': 'north_america-> atlantic_ocean', 'support': 5},
#  {'pattern': 'north_america-> atlantic_ocean-> tropical_cyclone',
#   'support': 5},
#  {'pattern': 'north_america-> atlantic_ocean-> tropical_cyclone-> hurricane_katrina',
#   'support': 5},
#  {'pattern': 'north_america-> atlantic_ocean-> hurricane_katrina',
#   'support': 5},
#  {'pattern': 'north_america-> atlantic_ocean-> africa', 'support': 5},
#  {'pattern': 'north_america-> tropical_cyclone', 'support': 5},
#  {'pattern': 'north_america-> tropical_cyclone-> hurricane_katrina',
#   'support': 5},
#  {'pattern': 'north_america-> rocky_mountains', 'support': 5},
#  {'pattern': 'north_america-> rocky_mountains-> skiing', 'support': 5},
#  {'pattern': 'north_america-> skiing', 'support': 5},
#  {'pattern': 'north_america-> ecuador', 'support': 5},
#  {'pattern': 'north_america-> florida', 'support': 5},
#  {'pattern': 'north_america-> florida-> houston%2c_texas', 'support': 5},
#  {'pattern': 'north_america-> houston%2c_texas', 'support': 5},
#  {'pattern': 'north_america-> africa', 'support': 5},
#  {'pattern': 'north_america-> earth', 'support': 5},
#  {'pattern': 'north_america-> canada', 'support': 5},
#  {'pattern': 'united_states', 'support': 6},
#  {'pattern': 'united_states-> president_of_the_united_states', 'support': 6},
#  {'pattern': 'united_states-> president_of_the_united_states-> chester_a._arthur',
#   'support': 6},
#  {'pattern': 'united_states-> president_of_the_united_states-> james_monroe',
#   'support': 6},
#  {'pattern': 'united_states-> president_of_the_united_states-> harry_s._truman',
#   'support': 6},
#  {'pattern': 'united_states-> president_of_the_united_states-> bill_clinton',
#   'support': 6},
#  {'pattern': 'united_states-> walt_whitman', 'support': 6},
#  {'pattern': 'united_states-> walt_whitman-> henry_david_thoreau',
#   'support': 6},
#  {'pattern': 'united_states-> poetry_of_the_united_states', 'support': 6},
#  {'pattern': 'united_states-> henry_david_thoreau', 'support': 6},
#  {'pattern': 'united_states-> art', 'support': 6},
#  {'pattern': 'united_states-> medicine', 'support': 6},
#  {'pattern': 'united_states-> science', 'support': 6},
#  {'pattern': 'united_states-> chemistry', 'support': 5},
#  {'pattern': 'united_states-> carbon', 'support': 5},
#  {'pattern': 'united_states-> george_washington', 'support': 5},
#  {'pattern': 'united_states-> george_washington-> american_revolutionary_war',
#   'support': 5},
#  {'pattern': 'united_states-> american_revolutionary_war', 'support': 5},
#  {'pattern': 'united_states-> james_ii_of_england', 'support': 5},
#  {'pattern': 'united_states-> jazz', 'support': 5},
#  {'pattern': 'united_states-> country', 'support': 5},
#  {'pattern': 'united_states-> country-> united_nations', 'support': 5},
#  {'pattern': 'united_states-> country-> egypt', 'support': 5},
#  {'pattern': 'united_states-> country-> egypt-> egyptian_pyramids',
#   'support': 5},
#  {'pattern': 'united_states-> country-> egypt-> egyptian_pyramids-> pyramid',
#   'support': 5},
#  {'pattern': 'united_states-> country-> egypt-> pyramid', 'support': 5},
#  {'pattern': 'united_states-> country-> egyptian_pyramids', 'support': 5},
#  {'pattern': 'united_states-> country-> egyptian_pyramids-> pyramid',
#   'support': 5},
#  {'pattern': 'united_states-> country-> pyramid', 'support': 5},
#  {'pattern': 'united_states-> country-> earth', 'support': 5},
#  {'pattern': 'united_states-> new_york_city', 'support': 5},
#  {'pattern': 'united_states-> new_york_city-> wall_street', 'support': 5},
#  {'pattern': 'united_states-> united_nations', 'support': 5},
#  {'pattern': 'united_states-> minnesota', 'support': 5},
#  {'pattern': 'united_states-> tennis', 'support': 5},
#  {'pattern': 'united_states-> education_in_the_united_states', 'support': 5},
#  {'pattern': 'united_states-> computer', 'support': 5},
#  {'pattern': 'united_states-> computer-> internet', 'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> microsoft', 'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> microsoft-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> world_wide_web-> google',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> world_wide_web-> gmail',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> world_wide_web-> gmail-> google',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> google', 'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> gmail', 'support': 5},
#  {'pattern': 'united_states-> computer-> internet-> gmail-> google',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> microsoft', 'support': 5},
#  {'pattern': 'united_states-> computer-> microsoft-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> microsoft_windows', 'support': 5},
#  {'pattern': 'united_states-> computer-> microsoft_windows-> internet',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> microsoft_windows-> internet-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> microsoft_windows-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> microsoft_windows-> windows_xp',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> world_wide_web', 'support': 5},
#  {'pattern': 'united_states-> computer-> world_wide_web-> google',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> world_wide_web-> gmail',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> world_wide_web-> gmail-> google',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> google', 'support': 5},
#  {'pattern': 'united_states-> computer-> gmail', 'support': 5},
#  {'pattern': 'united_states-> computer-> gmail-> google', 'support': 5},
#  {'pattern': 'united_states-> computer-> computer_and_video_games',
#   'support': 5},
#  {'pattern': 'united_states-> computer-> windows_xp', 'support': 5},
#  {'pattern': 'united_states-> internet', 'support': 5},
#  {'pattern': 'united_states-> internet-> microsoft', 'support': 5},
#  {'pattern': 'united_states-> internet-> microsoft-> microsoft_windows',
#   'support': 5},
#  {'pattern': 'united_states-> internet-> microsoft-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> internet-> microsoft-> world_wide_web-> google',
#   'support': 5},
#  {'pattern': 'united_states-> internet-> microsoft-> google', 'support': 5},
#  {'pattern': 'united_states-> internet-> microsoft_windows', 'support': 5},
#  {'pattern': 'united_states-> internet-> internet', 'support': 5},
#  {'pattern': 'united_states-> internet-> internet-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> internet-> world_wide_web', 'support': 5},
#  {'pattern': 'united_states-> internet-> world_wide_web-> google',
#   'support': 5},
#  {'pattern': 'united_states-> internet-> world_wide_web-> gmail',
#   'support': 5},
#  {'pattern': 'united_states-> internet-> world_wide_web-> gmail-> google',
#   'support': 5},
#  {'pattern': 'united_states-> internet-> google', 'support': 5},
#  {'pattern': 'united_states-> internet-> gmail', 'support': 5},
#  {'pattern': 'united_states-> internet-> gmail-> google', 'support': 5},
#  {'pattern': 'united_states-> internet-> literature', 'support': 5},
#  {'pattern': 'united_states-> microsoft', 'support': 5},
#  {'pattern': 'united_states-> microsoft-> microsoft_windows', 'support': 5},
#  {'pattern': 'united_states-> microsoft-> world_wide_web', 'support': 5},
#  {'pattern': 'united_states-> microsoft-> world_wide_web-> google',
#   'support': 5},
#  {'pattern': 'united_states-> microsoft-> google', 'support': 5},
#  {'pattern': 'united_states-> microsoft_windows', 'support': 5},
#  {'pattern': 'united_states-> microsoft_windows-> internet', 'support': 5},
#  {'pattern': 'united_states-> microsoft_windows-> internet-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> microsoft_windows-> world_wide_web',
#   'support': 5},
#  {'pattern': 'united_states-> microsoft_windows-> windows_xp', 'support': 5},
#  {'pattern': 'united_states-> world_wide_web', 'support': 5},
#  {'pattern': 'united_states-> world_wide_web-> google', 'support': 5},
#  {'pattern': 'united_states-> world_wide_web-> gmail', 'support': 5},
#  ...]

# %% [markdown]
# ### Refrences

# %% [markdown]
# 1. [Generalized Sequential Pattern Mining with Item Intervals](https://www.researchgate.net/publication/42803299_Generalized_Sequential_Pattern_Mining_with_Item_Intervals?enrichId=rgreq-59fcced5778bfc7cb6b286c585bbc9fa-XXX&enrichSource=Y292ZXJQYWdlOzQyODAzMjk5O0FTOjEzNDczNTY3MDAyNjI0MEAxNDA5MTM0ODk1MTA3&el=1_x_3&_esc=publicationCoverPdf)
#
# 2. [PrefixSpan: Mining Sequential Patterns Efficiently by Prefix-Projected Pattern Growth](https://ieeexplore.ieee.org/abstract/document/914830)
